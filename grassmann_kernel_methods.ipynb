# %% [markdown]
# # Grassmann Kernels

# %% [markdown]
# For more information see [Expanding the Family of Grassmannian Kernels: An Embedding Perspective](https://arxiv.org/abs/1407.1123).
#
# Suppose we are given the following list of kernels on the Grassmannian:
# 1. Polynomial: $K_{p, bc}(X, Y) = (\beta + |\det(X^T Y)|)^{\alpha}, \beta >0$
# 2. RBF: $K_{r, bc}(X, Y) = \exp(\beta|\det(X^T Y)|), \beta >0$
# 3. Laplace: $K_{l, bc}(X, Y) = \exp(-\beta \sqrt{1-|\det(X^T Y)|}), \beta >0$
# 4. Binomial: $K_{bi, bc}(X, Y) = (\beta - |\det(X^T Y)|)^{\alpha}, \beta >1$
# 5. Lorgarithm: $K_{log, bc}(X, Y) = -\log(2 - |\det(X^T Y)|)$
#
# Where we use the inner product $\langle X, Y \rangle_P =  |P(X)^TP(Y)| = |\det(X^T Y)|$ as the inner product on the Plücker embeddings $P(X)$ and $P(Y)$. This inner product induces the distance metric $d_{bc}(X, Y) = ||P(X) - P(Y)||^2 = 2 - 2|\det(X^T Y)|$, which is the same as the geodesic distance $d_g(X, Y)$ up to scale $\sqrt{2}$. Please explain how this might be used in our context.
#
# The provided list of kernels provides different ways of calculating the similarity between points on the Grassmannian, using the Plücker embedding. These kernels can be used in machine learning algorithms to compute the similarity between subspaces represented by the matrices $X$ and $Y$.
#
# The choice of kernel depends on the nature of your data and the problem you are trying to solve. Here is a high-level description of how each kernel could be useful:
#
# 1. **Polynomial Kernel**: This kernel measures the similarity between $X$ and $Y$ as a power of their inner product plus a constant $\beta$. This can be useful when you want to capture more complex relationships between your data points that might not be linearly separable in the original space.
#
# 2. **RBF (Radial Basis Function) Kernel**: This is an exponential kernel, which can capture a wide range of relationships between data points. It is one of the most commonly used kernels in machine learning and can handle non-linear relationships well.
#
# 3. **Laplace Kernel**: The Laplace kernel is similar to the RBF kernel but with the difference that it is less sensitive to changes in the determinant of $X^T Y$. This can make it more robust to variations in the data.
#
# 4. **Binomial Kernel**: This kernel measures similarity as a power of the difference between a constant $\beta$ and the inner product. Like the polynomial kernel, it can capture complex relationships between data points.
#
# 5. **Logarithm Kernel**: The logarithm kernel is unique in the sense that it directly uses the logarithm of the inner product. This can be useful if the relationships between your data are best captured by a logarithmic function.
#
# The distance metric $d_{bc}(X, Y)$ is derived from the inner product and essentially measures the "distance" between points in the Grassmannian in terms of the determinant of their inner product. This distance is equivalent to the geodesic distance, up to a scaling factor of $\sqrt{2}$. The geodesic distance is the shortest path between two points in a curved space, like the Grassmannian.
#
# In the context of machine learning, these kernels and the distance metric can be used in many algorithms that involve measuring similarity or distance between data points. For example, they can be used in support vector machines (SVMs), kernelized regression, or clustering algorithms operating on data points in the Grassmannian. The choice of kernel can significantly influence the performance of these algorithms, so it would be important to choose a kernel that is appropriate for your specific task and data.

# %%
import numpy as np

def gram_schmidt(X):
    Q, R = np.linalg.qr(X)
    return Q

def polynomial_kernel(X, Y, alpha, beta):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return (beta + inner_product_det) ** alpha

def rbf_kernel(X, Y, beta):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return np.exp(-beta * (1 - inner_product_det))

def laplace_kernel(X, Y, beta):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return np.exp(-beta * np.sqrt(1 - inner_product_det))

def binomial_kernel(X, Y, alpha, beta):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return (alpha - inner_product_det) ** beta

def logarithm_kernel(X, Y):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return -np.log(2 - inner_product_det)

def bc_distance(X, Y):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return np.arccos(np.sqrt(inner_product_det))

# %%
X = np.random.rand(3,2)
Y = np.random.rand(3,2)
alpha = 2
beta = 3
bc_distance(X, Y)
# Out:
# 0.8196546783111077

# %%
polynomial_kernel(X, Y, alpha, beta)
# Out:
# 12.011563626881381

# %%
rbf_kernel(X, Y, beta)
# Out:
# 0.20135431471900322

# %%
laplace_kernel(X, Y, beta)
# Out:
# 0.11161156547948795

# %%
binomial_kernel(X, Y, alpha, beta)
# Out:
# 3.611363254832913

# %%
logarithm_kernel(X, Y)
# Out:
# -0.4280284446590432

# %% [markdown]
# Before starting the discussion, let's introduce some notations and assumptions.
#
# - $\Delta W_i^{(n)}$: The $n^{th}$ layer's update weight matrix in the $i^{th}$ Low Rank Adaptation (LoRA) model. Assume there are $K$ models, and each model has $N$ layers. Thus, $i \in \{1,2,...,K\}$ and $n \in \{1,2,...,N\}$.
# - $\{Gr(p, V)\}$: A Grassmann manifold, which is a space of $p$-dimensional linear subspaces of $V$.
#
# Let's denote the kernel function as $k(\cdot, \cdot)$, which can be any of the five kernels mentioned above (Polynomial, RBF, Laplace, Binomial, or Logarithm). The kernel function calculates the similarity between two points on the Grassmann manifold, represented by their respective U matrices obtained from the SVD of the update weight matrices.
#
# The first step in clustering involves calculating the pairwise similarity between all points. This gives us a similarity matrix $K$ where the element $K_{ij}$ is the similarity between points $i$ and $j$, calculated using the kernel function on the Grassmann manifold.
#
# $$ K_{ij} = k(U_{\Delta W_i^{(n)}}, U_{\Delta W_j^{(m)}}) $$
#
# After calculating the similarity matrix, we can apply a clustering algorithm, such as k-means or spectral clustering, directly on the similarity matrix.
#
# In the case of k-means, we aim to minimize the within-cluster sum of squares (WCSS), which is the sum of the squared distances between each point and the centroid of its assigned cluster. In our context, the distance between two points is defined in terms of the Binet-Cauchy distance, as follows:
#
# $$ d_{bc}(\Delta W_i^{(n)}, \Delta W_j^{(m)}) = 2 - 2 \cdot \left| \det(U_{\Delta W_i^{(n)}}^T U_{\Delta W_j^{(m)}}) \right| $$
#
# The k-means clustering algorithm involves the following steps:
#
# 1. Initialize $k$ centroids randomly.
# 2. Assign each point to the cluster that has the closest centroid.
# 3. Update the centroids by calculating the geometric mean of all points in the cluster.
# 4. Repeat steps 2 and 3 until convergence.
#
# On the other hand, spectral clustering uses the eigenvectors of the Laplacian matrix, which is defined based on the similarity matrix, to perform dimensionality reduction before applying a standard clustering algorithm like k-means.
#
# While these steps outline the general process of clustering, please note that clustering on Grassmann manifolds involves additional complexities due to the non-Euclidean nature of the space. These complexities may require the use of specialized algorithms or adaptations of existing algorithms to effectively work with the Grassmann manifold geometry.
#
# Moreover, the process of finding the geometric mean (or centroid) in a Grassmann manifold is not straightforward and involves the minimization of a cost function defined over the manifold, such as the sum of squared geodesic distances to all points in the cluster. This process may involve iterative methods or the use of optimization techniques that take into account the manifold's structure.
#
# Finally, remember to validate the assumptions and constraints of the specific application, and make sure to choose the kernel and clustering method that best suit the problem at hand.

# %% [markdown]
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a density-based clustering algorithm, which groups together points in dense regions and separates points in sparse regions.
#
# The DBSCAN algorithm requires two parameters:
#
# 1. `eps`: the maximum distance between two samples for them to be considered as in the same neighborhood.
# 2. `min_samples`: the number of samples in a neighborhood for a point to be considered as a core point.
#
# In the context of Grassmann manifolds, we'll use the Binet-Cauchy distance $d_{bc}$ as defined previously:
#
# $$ d_{bc}(X, Y) = 2 - 2 \cdot \left| \det(X^T Y) \right| $$
#
# Here is how the DBSCAN algorithm can be applied in our context:
#
# 1. For each point $p$ in our dataset, we compute the neighborhood $N_{eps}(p)$, which is the set of points whose distance to $p$ is less than `eps`:
#
# $$
# N_{\epsilon}(p) = \{q : d_{bc}(p, q) \leq \epsilon \}
# $$
#
# 2. If a point $p$ has at least `min_samples` in its `eps`-neighborhood (including $p$ itself), we consider $p$ as a core point. Formally, $p$ is a core point if:
#
# $$
# \left| N_{\epsilon}(p)\right| \geq \text{min\_samples}
# $$
#
# 3. We create a cluster for each core point and its reachable points. A point $q$ is directly reachable from a point $p$ if $q$ is within `eps` distance from $p$ and $p$ is a core point. A point $q$ is reachable from $p$ if there is a sequence of points $p_1, ..., p_n$ with $p_1=p$ and $p_n=q$ such that each point $p_{i+1}$ is directly reachable from $p_i$.
#
# 4. Assign each point to the cluster of the nearest core point. If a point is not reachable from any core point, it's considered as noise.
#
# In practice, DBSCAN can be sensitive to the choice of `eps` and `min_samples` parameters, and different choices can lead to very different clustering results. It's often recommended to normalize the data before applying DBSCAN, but in the context of Grassmann manifolds, the points are already on a unit sphere due to the properties of the SVD.

# %% [markdown]
# Kernel methods can be used for clustering in a variety of ways. The basic idea is to use the kernel function to map the input data into a higher-dimensional space, where clusters might be more easily discernible.
#
# One popular method is Kernel K-means, which is a variant of the K-means clustering algorithm. In the standard K-means algorithm, the goal is to partition the data into K clusters such that the within-cluster sum of squares is minimized:
#
# $$ \min_{S} \sum_{i=1}^{k} \sum_{\mathbf{x} \in S_i} \|\mathbf{x} - \mathbf{\mu}_i\|^2 $$
#
# where $\mu_i$ is the mean of points in $S_i$.
#
# In the Kernel K-means version, we replace the Euclidean distance with a distance measure in the feature space induced by a kernel function $K$. This is equivalent to performing K-means in this higher-dimensional space, and the objective function becomes:
#
# $$ \min_{S} \sum_{i=1}^{k} \sum_{\mathbf{x}, \mathbf{z} \in S_i} K(\mathbf{x}, \mathbf{x}) + K(\mathbf{z}, \mathbf{z}) - 2K(\mathbf{x}, \mathbf{z}) $$
#
# The Spectral Clustering method also uses kernel matrices. It uses the eigenvectors of the Laplacian of the kernel matrix to perform dimensionality reduction, then applies a clustering algorithm (like K-means) in the reduced space.
#
# The Laplacian $L$ of a kernel matrix $K$ is computed as $L = D - K$, where $D$ is a diagonal matrix where $D_{ii}$ is the sum of the $i$-th row of $K$. After computing $L$, the algorithm finds the $k$ smallest eigenvectors, and forms a new matrix where the $i$-th row is the $i$-th eigenvector. Finally, K-means is performed on this new matrix to get the clusters.

# %%
import numpy as np
from scipy.linalg import subspace_angles

def gram_schmidt(X):
    Q, R = np.linalg.qr(X)
    return Q

def polynomial_kernel(X, Y, alpha, beta):
    Q_X = gram_schmidt(X)
    Q_Y = gram_schmidt(Y)
    inner_product_det = np.abs(np.linalg.det(Q_X.T @ Q_Y))
    return (beta + inner_product_det) ** alpha

# Number of subspaces (i.e., data points)
num_subspaces = 5

# Dimension of ambient space
ambient_dim = 5

# Dimension of each subspace
subspace_dim = 3

# Generate a list of random subspaces
X = [np.random.randn(ambient_dim, subspace_dim) for _ in range(num_subspaces)]

alpha = 2
beta = 3

# Initialize an empty matrix for the kernel matrix
K = np.zeros((num_subspaces, num_subspaces))

for i in range(num_subspaces):
    for j in range(num_subspaces):
        K[i, j] = polynomial_kernel(X[i], X[j], alpha, beta)

print(K)
# Out:
# [[16.          9.2664217  10.1434243  10.65910497 11.30017748]
#  [ 9.2664217  16.         12.04407451 10.26218048 10.0785779 ]
#  [10.1434243  12.04407451 16.          9.38791207 11.01756676]
#  [10.65910497 10.26218048  9.38791207 16.          9.75727678]
#  [11.30017748 10.0785779  11.01756676  9.75727678 16.        ]]

# %%
from safetensors import safe_open
from scipy.linalg import svd
import numpy as np

# Load the LoRA tensors from .safetensors files
with safe_open("fashigirl-v5.5-lora-naivae-64dim.safetensors", framework="pt", device="cpu") as f:
    lora1_tensors = {}
    for k in f.keys():
        lora1_tensors[k] = f.get_tensor(k)

with safe_open("lora2.safetensors", framework="pt", device="cpu") as f:
    lora2_tensors = {}
    for k in f.keys():
        lora2_tensors[k] = f.get_tensor(k)

# %%
import torch

# Gather all keys and sort them
all_keys = sorted(list(lora1_tensors.keys()))

# Filter keys for lora_down and lora_up pairs
lora_down_keys = [key for key in all_keys if 'lora_down' in key]
lora_up_keys = [key for key in all_keys if 'lora_up' in key]

# Ensure we have matching pairs of keys
assert len(lora_down_keys) == len(lora_up_keys), "Mismatch in number of 'lora_down' and 'lora_up' keys"

# Define the subspace similarity measure
def phi(U1, U2, i, j):
    U1_i = U1[:, :i]  # First i columns of U1
    U2_j = U2[:, :j]  # First j columns of U2
    
    product = torch.matmul(U1_i.t(), U2_j)  # Matrix multiplication
    norm = torch.norm(product)  # Frobenius norm
    
    return norm ** 2 / min(i, j)

# Iterate over all layers
for layer in range(len(lora_down_keys)):
    try:
        # Extract the corresponding A and B matrices
        A1 = lora1_tensors[lora_down_keys[layer]].float()
        B1 = lora1_tensors[lora_up_keys[layer]].float()

        A2 = lora2_tensors[lora_down_keys[layer]].float()
        B2 = lora2_tensors[lora_up_keys[layer]].float()

        # Print the shapes of A1 and B1 matrices for troubleshooting
        print(f"A1 shape: {A1.shape}")
        print(f"B1 shape: {B1.shape}")

        print(f"A2 shape: {A2.shape}")
        print(f"B2 shape: {B2.shape}")

        # Compute the update matrices
        Delta_W1 = torch.matmul(B1, A1)
        print(f"ΔW1 shape: {Delta_W1.shape}")
        Delta_W2 = torch.matmul(B2, A2)
        print(f"ΔW2 shape: {Delta_W2.shape}")


        # Compute the SVD of the update matrices
        U1, _, _ = torch.svd(Delta_W1)
        U2, _, _ = torch.svd(Delta_W2)

        # Calculate the subspace similarity measure
        i = U1.size(1)  # Number of columns in U1
        j = U2.size(1)  # Number of columns in U2
        alpha = 2
        beta = 3
        result = polynomial_kernel(U1, U2, alpha, beta)  # Replace i and j with the desired values

        print(f"The polynomial kernel similarity measure for layer {layer} is: {result}")

    except RuntimeError as e:
        # Print the layer number and the error message
        print(f"Error occurred at layer {layer}: {e}")
# Out:
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 0 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 1 is: 15.999998092651424
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 2 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 3 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 4 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 5 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 6 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 7 is: 15.999999046325698
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 8 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 9 is: 15.999997615814298
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 10 is: 16.000004768371937
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 11 is: 15.999996185302962
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 12 is: 16.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 13 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 14 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 15 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 16 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 17 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 18 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 19 is: 16.00000762939544
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 20 is: 16.00000667572091
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 21 is: 15.999988079073265
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 22 is: 15.999992847443426
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 23 is: 15.999997615814298
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 24 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 25 is: 15.999999046325698
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 26 is: 16.000002861023077
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 27 is: 16.00000572204641
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 28 is: 15.999998569488557
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 29 is: 16.00000572204641
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 30 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 31 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 32 is: 15.999996185302962
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 33 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 34 is: 16.000003814697493
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 35 is: 15.999993324280481
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 36 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 37 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 38 is: 16.000002861023077
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 39 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 40 is: 16.00000572204641
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 41 is: 16.000003814697493
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 42 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 43 is: 15.999997138977179
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 44 is: 15.999991893769337
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 45 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 46 is: 15.99999475479169
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 47 is: 15.999995708465864
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 48 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 49 is: 16.00000762939544
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 50 is: 15.999992847443426
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 51 is: 15.999992847443426
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 52 is: 15.999999046325698
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 53 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 54 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 55 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 56 is: 15.999993324280481
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 57 is: 15.999992370606378
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 58 is: 15.999995231628773
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 59 is: 15.999999523162845
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 60 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 61 is: 15.999999523162845
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 62 is: 16.00000762939544
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 63 is: 16.0
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 64 is: 16.000003814697493
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 65 is: 15.999998569488557
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([3072, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([3072, 64])
# ΔW1 shape: torch.Size([3072, 768])
# ΔW2 shape: torch.Size([3072, 768])
# The polynomial kernel similarity measure for layer 66 is: 9.0
# A1 shape: torch.Size([64, 3072])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 3072])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 3072])
# ΔW2 shape: torch.Size([768, 3072])
# The polynomial kernel similarity measure for layer 67 is: 15.999995708465864
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 68 is: 15.999998092651424
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 69 is: 16.00000572204641
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 70 is: 16.00000858307
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([768, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([768, 64])
# ΔW1 shape: torch.Size([768, 768])
# ΔW2 shape: torch.Size([768, 768])
# The polynomial kernel similarity measure for layer 71 is: 16.00000095367433
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 72: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 73: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 74 is: 16.00000190734869
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 75 is: 15.999999523162845
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 76 is: 16.000002861023077
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 77 is: 15.999994277954613
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 78 is: 16.00000762939544
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 79 is: 15.999999046325698
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 80 is: 16.000002861023077
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 81 is: 16.00000095367433
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([2560, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([2560, 64])
# ΔW1 shape: torch.Size([2560, 320])
# ΔW2 shape: torch.Size([2560, 320])
# The polynomial kernel similarity measure for layer 82 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 1280])
# ΔW2 shape: torch.Size([320, 1280])
# The polynomial kernel similarity measure for layer 83 is: 16.00000762939544
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 84: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 85: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 86 is: 16.00000572204641
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 87 is: 15.999998569488557
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 88 is: 15.999998092651424
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 89 is: 16.00000572204641
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 90 is: 16.000003814697493
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 91 is: 16.00000190734869
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 92 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 93 is: 16.00000572204641
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([2560, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([2560, 64])
# ΔW1 shape: torch.Size([2560, 320])
# ΔW2 shape: torch.Size([2560, 320])
# The polynomial kernel similarity measure for layer 94 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 1280])
# ΔW2 shape: torch.Size([320, 1280])
# The polynomial kernel similarity measure for layer 95 is: 16.000002861023077
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 96: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 97: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 98 is: 15.999995708465864
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 99 is: 16.00000572204641
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 100 is: 16.00000095367433
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 101 is: 15.999993324280481
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 102 is: 16.00000190734869
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 103 is: 16.00000858307
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 104 is: 16.00000667572091
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 105 is: 15.999992847443426
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([5120, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([5120, 64])
# ΔW1 shape: torch.Size([5120, 640])
# ΔW2 shape: torch.Size([5120, 640])
# The polynomial kernel similarity measure for layer 106 is: 9.0
# A1 shape: torch.Size([64, 2560])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 2560])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 2560])
# ΔW2 shape: torch.Size([640, 2560])
# The polynomial kernel similarity measure for layer 107 is: 16.00000095367433
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 108: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 109: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 110 is: 15.999987602236288
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 111 is: 16.000002861023077
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 112 is: 15.999994277954613
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 113 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 114 is: 15.999997615814298
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 115 is: 15.999997615814298
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 116 is: 15.999994277954613
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 117 is: 15.999999046325698
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([5120, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([5120, 64])
# ΔW1 shape: torch.Size([5120, 640])
# ΔW2 shape: torch.Size([5120, 640])
# The polynomial kernel similarity measure for layer 118 is: 9.0
# A1 shape: torch.Size([64, 2560])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 2560])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 2560])
# ΔW2 shape: torch.Size([640, 2560])
# The polynomial kernel similarity measure for layer 119 is: 16.0
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 120: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 121: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 122 is: 16.00000095367433
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 123 is: 16.000002861023077
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 124 is: 16.00000190734869
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 125 is: 15.999990463258257
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 126 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 127 is: 15.999990463258257
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 128 is: 15.999999523162845
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 129 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([10240, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([10240, 64])
# ΔW1 shape: torch.Size([10240, 1280])
# ΔW2 shape: torch.Size([10240, 1280])
# The polynomial kernel similarity measure for layer 130 is: 9.0
# A1 shape: torch.Size([64, 5120])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 5120])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 5120])
# ΔW2 shape: torch.Size([1280, 5120])
# The polynomial kernel similarity measure for layer 131 is: 15.999998569488557
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 132: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 133: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 134 is: 16.00000762939544
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 135 is: 16.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 136 is: 15.999989509584239
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 137 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 138 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 139 is: 16.000004768371937
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 140 is: 15.999992370606378
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 141 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([10240, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([10240, 64])
# ΔW1 shape: torch.Size([10240, 1280])
# ΔW2 shape: torch.Size([10240, 1280])
# The polynomial kernel similarity measure for layer 142 is: 9.0
# A1 shape: torch.Size([64, 5120])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 5120])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 5120])
# ΔW2 shape: torch.Size([1280, 5120])
# The polynomial kernel similarity measure for layer 143 is: 15.999998569488557
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 144: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 145: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 146 is: 16.00000858307
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 147 is: 15.99999475479169
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 148 is: 16.000003814697493
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 149 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 150 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 151 is: 15.999997615814298
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 152 is: 16.000002861023077
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 153 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([10240, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([10240, 64])
# ΔW1 shape: torch.Size([10240, 1280])
# ΔW2 shape: torch.Size([10240, 1280])
# The polynomial kernel similarity measure for layer 154 is: 9.0
# A1 shape: torch.Size([64, 5120])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 5120])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 5120])
# ΔW2 shape: torch.Size([1280, 5120])
# The polynomial kernel similarity measure for layer 155 is: 15.999992847443426
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 156: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 157: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 158 is: 16.000003814697493
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 159 is: 15.999992847443426
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 160 is: 15.999992847443426
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 161 is: 15.999997615814298
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 162 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 163 is: 15.999995231628773
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 164 is: 16.00000762939544
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 165 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([10240, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([10240, 64])
# ΔW1 shape: torch.Size([10240, 1280])
# ΔW2 shape: torch.Size([10240, 1280])
# The polynomial kernel similarity measure for layer 166 is: 9.0
# A1 shape: torch.Size([64, 5120])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 5120])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 5120])
# ΔW2 shape: torch.Size([1280, 5120])
# The polynomial kernel similarity measure for layer 167 is: 15.999993801117544
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 168: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280, 1, 1])
# B1 shape: torch.Size([1280, 64, 1, 1])
# A2 shape: torch.Size([64, 1280, 1, 1])
# B2 shape: torch.Size([1280, 64, 1, 1])
# Error occurred at layer 169: The size of tensor a (64) must match the size of tensor b (1280) at non-singleton dimension 1
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 170 is: 16.00000858307
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 171 is: 16.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 172 is: 15.999995708465864
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 173 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 768])
# ΔW2 shape: torch.Size([1280, 768])
# The polynomial kernel similarity measure for layer 174 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([1280, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([1280, 64])
# ΔW1 shape: torch.Size([1280, 1280])
# ΔW2 shape: torch.Size([1280, 1280])
# The polynomial kernel similarity measure for layer 175 is: 16.00000190734869
# ...
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 205: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 206 is: 16.00000095367433
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 207 is: 15.999998569488557
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 208 is: 16.00000095367433
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 209 is: 15.999999523162845
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 210 is: 15.999997138977179
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 211 is: 15.999992847443426
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 212 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 213 is: 16.000003814697493
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([5120, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([5120, 64])
# ΔW1 shape: torch.Size([5120, 640])
# ΔW2 shape: torch.Size([5120, 640])
# The polynomial kernel similarity measure for layer 214 is: 9.0
# A1 shape: torch.Size([64, 2560])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 2560])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 2560])
# ΔW2 shape: torch.Size([640, 2560])
# The polynomial kernel similarity measure for layer 215 is: 16.000002861023077
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 216: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640, 1, 1])
# B1 shape: torch.Size([640, 64, 1, 1])
# A2 shape: torch.Size([64, 640, 1, 1])
# B2 shape: torch.Size([640, 64, 1, 1])
# Error occurred at layer 217: The size of tensor a (64) must match the size of tensor b (640) at non-singleton dimension 1
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 218 is: 15.999998569488557
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 219 is: 15.999993324280481
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 220 is: 15.999993801117544
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 221 is: 16.00000095367433
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 222 is: 15.999998092651424
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 223 is: 16.00000858307
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 640])
# ΔW2 shape: torch.Size([640, 640])
# The polynomial kernel similarity measure for layer 224 is: 16.00000762939544
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 768])
# ΔW2 shape: torch.Size([640, 768])
# The polynomial kernel similarity measure for layer 225 is: 15.999999523162845
# A1 shape: torch.Size([64, 640])
# B1 shape: torch.Size([5120, 64])
# A2 shape: torch.Size([64, 640])
# B2 shape: torch.Size([5120, 64])
# ΔW1 shape: torch.Size([5120, 640])
# ΔW2 shape: torch.Size([5120, 640])
# The polynomial kernel similarity measure for layer 226 is: 9.0
# A1 shape: torch.Size([64, 2560])
# B1 shape: torch.Size([640, 64])
# A2 shape: torch.Size([64, 2560])
# B2 shape: torch.Size([640, 64])
# ΔW1 shape: torch.Size([640, 2560])
# ΔW2 shape: torch.Size([640, 2560])
# The polynomial kernel similarity measure for layer 227 is: 16.00000095367433
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 228: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 229: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 230 is: 16.00000095367433
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 231 is: 15.999995231628773
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 232 is: 15.999998569488557
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 233 is: 16.00000190734869
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 234 is: 16.000003814697493
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 235 is: 16.00000667572091
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 236 is: 16.000004768371937
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 237 is: 15.999996662140067
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([2560, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([2560, 64])
# ΔW1 shape: torch.Size([2560, 320])
# ΔW2 shape: torch.Size([2560, 320])
# The polynomial kernel similarity measure for layer 238 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 1280])
# ΔW2 shape: torch.Size([320, 1280])
# The polynomial kernel similarity measure for layer 239 is: 15.999996662140067
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 240: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 241: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 242 is: 16.00000190734869
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 243 is: 16.00000095367433
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 244 is: 16.0
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 245 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 246 is: 15.999997615814298
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 247 is: 16.00000095367433
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 248 is: 15.999996662140067
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 249 is: 16.0
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([2560, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([2560, 64])
# ΔW1 shape: torch.Size([2560, 320])
# ΔW2 shape: torch.Size([2560, 320])
# The polynomial kernel similarity measure for layer 250 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 1280])
# ΔW2 shape: torch.Size([320, 1280])
# The polynomial kernel similarity measure for layer 251 is: 15.999997138977179
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 252: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320, 1, 1])
# B1 shape: torch.Size([320, 64, 1, 1])
# A2 shape: torch.Size([64, 320, 1, 1])
# B2 shape: torch.Size([320, 64, 1, 1])
# Error occurred at layer 253: The size of tensor a (64) must match the size of tensor b (320) at non-singleton dimension 1
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 254 is: 16.000002861023077
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 255 is: 15.999999523162845
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 256 is: 16.000002861023077
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 257 is: 15.999991416932303
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 258 is: 15.999997615814298
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 259 is: 16.000004768371937
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 320])
# ΔW2 shape: torch.Size([320, 320])
# The polynomial kernel similarity measure for layer 260 is: 15.999998092651424
# A1 shape: torch.Size([64, 768])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 768])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 768])
# ΔW2 shape: torch.Size([320, 768])
# The polynomial kernel similarity measure for layer 261 is: 15.999998092651424
# A1 shape: torch.Size([64, 320])
# B1 shape: torch.Size([2560, 64])
# A2 shape: torch.Size([64, 320])
# B2 shape: torch.Size([2560, 64])
# ΔW1 shape: torch.Size([2560, 320])
# ΔW2 shape: torch.Size([2560, 320])
# The polynomial kernel similarity measure for layer 262 is: 9.0
# A1 shape: torch.Size([64, 1280])
# B1 shape: torch.Size([320, 64])
# A2 shape: torch.Size([64, 1280])
# B2 shape: torch.Size([320, 64])
# ΔW1 shape: torch.Size([320, 1280])
# ΔW2 shape: torch.Size([320, 1280])
# The polynomial kernel similarity measure for layer 263 is: 15.999998569488557
